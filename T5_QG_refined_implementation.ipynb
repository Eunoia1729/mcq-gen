# %% [markdown]
# ## Installing Code Modules and Dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U transformers==3.0.0
# Out:
# Collecting transformers==3.0.0
#   Downloading https://files.pythonhosted.org/packages/9c/35/1c3f6e62d81f5f0daff1384e6d5e6c5758682a8357ebc765ece2b9def62b/transformers-3.0.0-py3-none-any.whl (754kB)
#      |████████████████████████████████| 757kB 5.7MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 27.7MB/s
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (20.9)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2.23.0)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2019.12.20)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 34.9MB/s
# Collecting tokenizers==0.8.0-rc4
#   Downloading https://files.pythonhosted.org/packages/f7/82/0e82a95bd9db2b32569500cc1bb47aa7c4e0f57aa5e35cceba414096917b/tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 41.7MB/s
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (3.0.12)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2020.12.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.15.0)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (7.1.2)
# Installing collected packages: sentencepiece, sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.45 sentencepiece-0.1.95 tokenizers-0.8.0rc4 transformers-3.0.0

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from nltk import sent_tokenize
import itertools
import logging
from typing import Optional, Dict, Union
import torch
from transformers import(
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
)
logger = logging.getLogger(__name__)

class QGPipeline:
    """Poor man's QG pipeline"""
    def __init__(
        self,
        model: PreTrainedModel,
        tokenizer: PreTrainedTokenizer,
        ans_model: PreTrainedModel,
        ans_tokenizer: PreTrainedTokenizer,
        qg_format: str,
        use_cuda: bool
    ):
        self.model = model
        self.tokenizer = tokenizer

        self.ans_model = ans_model
        self.ans_tokenizer = ans_tokenizer

        self.qg_format = qg_format

        self.device = "cuda" if torch.cuda.is_available() and use_cuda else "cpu"
        self.model.to(self.device)

        if self.ans_model is not self.model:
            self.ans_model.to(self.device)

        assert self.model.__class__.__name__ in ["T5ForConditionalGeneration", "BartForConditionalGeneration"]

        if "T5ForConditionalGeneration" in self.model.__class__.__name__:
            self.model_type = "t5"
        else:
            self.model_type = "bart"

    def __call__(self, inputs: str):
        inputs = " ".join(inputs.split())
        sents, answers = self._extract_answers(inputs)
        flat_answers = list(itertools.chain(*answers))

        if len(flat_answers) == 0:
          return []

        if self.qg_format == "prepend":
            qg_examples = self._prepare_inputs_for_qg_from_answers_prepend(inputs, answers)
        else:
            qg_examples = self._prepare_inputs_for_qg_from_answers_hl(sents, answers)

        qg_inputs = [example['source_text'] for example in qg_examples]
        questions = self._generate_questions(qg_inputs)
        output = [{'answer': example['answer'], 'question': que} for example, que in zip(qg_examples, questions)]
        return output

    def _generate_questions(self, inputs):
        inputs = self._tokenize(inputs, padding=True, truncation=True)

        outs = self.model.generate(
            input_ids=inputs['input_ids'].to(self.device),
            attention_mask=inputs['attention_mask'].to(self.device),
            max_length=32,
            num_beams=4,
        )

        questions = [self.tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
        return questions

    def _extract_answers(self, context):
        sents, inputs = self._prepare_inputs_for_ans_extraction(context)
        inputs = self._tokenize(inputs, padding=True, truncation=True)

        outs = self.ans_model.generate(
            input_ids=inputs['input_ids'].to(self.device),
            attention_mask=inputs['attention_mask'].to(self.device),
            max_length=32,
        )

        dec = [self.ans_tokenizer.decode(ids, skip_special_tokens=False) for ids in outs]
        answers = [item.split('<sep>') for item in dec]
        answers = [i[:-1] for i in answers]

        return sents, answers

    def _tokenize(self,
        inputs,
        padding=True,
        truncation=True,
        add_special_tokens=True,
        max_length = 512
    ):
        inputs = self.tokenizer.batch_encode_plus(
            inputs,
            max_length=max_length,
            add_special_tokens=add_special_tokens,
            truncation=truncation,
            padding="max_length" if padding else False,
            pad_to_max_length=padding,
            return_tensors="pt"
        )
        return inputs

    def _prepare_inputs_for_ans_extraction(self, text):
        sents = sent_tokenize(text)

        inputs = []
        for i in range(len(sents)):
            source_text = "extract answers:"
            for j, sent in enumerate(sents):
                if i == j:
                    sent = "<hl> %s <hl>" % sent
                source_text = "%s %s" % (source_text, sent)
                source_text = source_text.strip()

            if self.model_type == "t5":
                source_text = source_text + " </s>"
            inputs.append(source_text)

        return sents, inputs

    def _prepare_inputs_for_qg_from_answers_hl(self, sents, answers):
        inputs = []
        for i, answer in enumerate(answers):
            if len(answer) == 0: continue
            for answer_text in answer:
                sent = sents[i]
                sents_copy = sents[:]

                answer_text = answer_text.strip()

                ans_start_idx = sent.index(answer_text)

                sent = f"{sent[:ans_start_idx]} <hl> {answer_text} <hl> {sent[ans_start_idx + len(answer_text): ]}"
                sents_copy[i] = sent

                source_text = " ".join(sents_copy)
                source_text = f"generate question: {source_text}"
                if self.model_type == "t5":
                    source_text = source_text + " </s>"

                inputs.append({"answer": answer_text, "source_text": source_text})

        return inputs

    def _prepare_inputs_for_qg_from_answers_prepend(self, context, answers):
        flat_answers = list(itertools.chain(*answers))
        examples = []
        for answer in flat_answers:
            source_text = f"answer: {answer} context: {context}"
            if self.model_type == "t5":
                source_text = source_text + " </s>"

            examples.append({"answer": answer, "source_text": source_text})
        return examples


class MultiTaskQAQGPipeline(QGPipeline):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def __call__(self, inputs: Union[Dict, str]):
        if type(inputs) is str:
            # do qg
            return super().__call__(inputs)
        else:
            # do qa
            return self._extract_answer(inputs["question"], inputs["context"])

    def _prepare_inputs_for_qa(self, question, context):
        source_text = f"question: {question}  context: {context}"
        if self.model_type == "t5":
            source_text = source_text + " </s>"
        return  source_text

    def _extract_answer(self, question, context):
        source_text = self._prepare_inputs_for_qa(question, context)
        inputs = self._tokenize([source_text], padding=False)

        outs = self.model.generate(
            input_ids=inputs['input_ids'].to(self.device),
            attention_mask=inputs['attention_mask'].to(self.device),
            max_length=16,
        )

        answer = self.tokenizer.decode(outs[0], skip_special_tokens=True)
        return answer

SUPPORTED_TASKS = {
    "multitask-qa-qg": {
        "impl": MultiTaskQAQGPipeline,
        "default": {
            "model": "valhalla/t5-small-qa-qg-hl",
        }
    }
}

def pipeline(
    task: str,
    model: Optional[Union[str, PreTrainedModel]] = None,
    tokenizer: Optional[Union[str, PreTrainedTokenizer]] = None,
    qg_format: Optional[str] = "highlight",
    ans_model: Optional[PreTrainedModel] = None,
    ans_tokenizer: Optional[Union[str, PreTrainedTokenizer]] = None,
    use_cuda: Optional[bool] = True,
    **kwargs,
):
    # Retrieve the task
    if task not in SUPPORTED_TASKS:
        raise KeyError("Unknown task {}, available tasks are {}".format(task, list(SUPPORTED_TASKS.keys())))

    targeted_task = SUPPORTED_TASKS[task]
    task_class = targeted_task["impl"]

    # Use default model/config/tokenizer for the task if no model is provided
    if model is None:
        model = targeted_task["default"]["model"]

    # Try to infer tokenizer from model or config name (if provided as str)
    if tokenizer is None:
        if isinstance(model, str):
            tokenizer = model
        else:
            # Impossible to guest what is the right tokenizer here
            raise Exception(
                "Impossible to guess which tokenizer to use. "
                "Please provided a PretrainedTokenizer class or a path/identifier to a pretrained tokenizer."
            )

    # Instantiate tokenizer if needed
    if isinstance(tokenizer, (str, tuple)):
        if isinstance(tokenizer, tuple):
            # For tuple we have (tokenizer name, {kwargs})
            tokenizer = AutoTokenizer.from_pretrained(tokenizer[0], **tokenizer[1])
        else:
            tokenizer = AutoTokenizer.from_pretrained(tokenizer)

    # Instantiate model if needed
    if isinstance(model, str):
        model = AutoModelForSeq2SeqLM.from_pretrained(model)
    return task_class(model=model, tokenizer=tokenizer, ans_model=model, ans_tokenizer=tokenizer, qg_format=qg_format, use_cuda=use_cuda)

# %%
import pprint
import gensim
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
# glove_file = '/content/drive/MyDrive/EdRes/glove.6B.300d.txt'
tmp_file = '/content/drive/MyDrive/EdRes/word2vec_glove.6B.300d.txt'

# %%
# glove2word2vec(glove_file, tmp_file)
model = KeyedVectors.load_word2vec_format(tmp_file)

# %%
def generateDistractors(answer, count = 3):
    answer = str.lower(answer)
    try:
        closestWords = model.most_similar(positive=[answer], topn=count)
    except:
        return []
    distractors = list(map(lambda x: x[0], closestWords))[0:count]
    return distractors

# %%
generateDistractors("Gandhi", 3)
# Out:
# ['mahatma', 'indira', 'rajiv']

# %% [markdown]
# ## Multitask QA-QG

# %%
sample_text = "Gravity (from Latin gravitas, meaning 'weight'), or gravitation, is a natural phenomenon by which all \
things with mass or energy—including planets, stars, galaxies, and even light—are brought toward (or gravitate toward) \
one another. On Earth, gravity gives weight to physical objects, and the Moon's gravity causes the ocean tides. \
The gravitational attraction of the original gaseous matter present in the Universe caused it to begin coalescing \
and forming stars and caused the stars to group together into galaxies, so gravity is responsible for many of \
the large-scale structures in the Universe. Gravity has an infinite range, although its effects become increasingly \
weaker as objects get further away"

# %% [markdown]
# ### base-model QG

# %%
base_qaqg_nlp = pipeline("multitask-qa-qg", model="valhalla/t5-base-qa-qg-hl")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=629.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=31.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=65.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=90.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891612585.0, style=ProgressStyle(descri…

# %% [markdown]
# #### QG

# %%
base_qaqg_nlp(sample_text)
# Out:
# [{'answer': 'gravitation', 'question': 'What is another name for gravity?'},
#  {'answer': 'Earth',
#   'question': 'On what planet does gravity give weight to physical objects?'},
#  {'answer': 'galaxies', 'question': 'What do the stars form into?'},
#  {'answer': 'weaker',
#   'question': "Gravity's effects become what as objects get further away?"}]

# %% [markdown]
# ## Testing

# %%
import random

# %%
def getFromTextFile(file_name):
  para = ""
  with open(file_name) as f:
    para = f.read()
  return para

# %%
def displayDistractors(choices):
  random.shuffle(choices)
  choice_index = ["a", "b", "c", "d"]
  for i in range(len(choices)):
    print(f"  {choice_index[i]}) {choices[i]}")

# %%
for i in range(6):
  generated_data = []
  para = getFromTextFile(f'/content/drive/MyDrive/EdRes/qg_test/test{i}.txt')
  # print(f'Results for test-{i} : ')
  try:
    results = base_qaqg_nlp(para)
    # print(f"PARAGRAPH-{i}")
    # print(para)

    # print("RESULTS")
    print(len(results))
    for result in results:
      if len(result['answer'].split()) > 1 :
        continue
      mcq_dict = {}
      choices = [result['answer']]
      distractors = generateDistractors(result['answer'], 4)
      choices = choices + distractors[1:4]
      if len(choices) == 1:
        continue
      random.shuffle(choices)
      mcq_dict['question'] = result['question']
      mcq_dict['answer'] = result['answer']
      mcq_dict['choices'] = choices
      generated_data.append(mcq_dict)
    pprint.pprint(generated_data)
  except Exception as e:
    print(f'Error in output, {e}')
# Out:
# 8
# [{'answer': 'Paging',
#   'choices': ['Paging', 'pager', 'cellular', 'telephony'],
#   'question': 'What is a memory management scheme that eliminates the need for '
#               'contiguous allocation of physical memory?'},
#  {'answer': 'TLB',
#   'choices': ['TLB', 'nke', 'nobe', 'propiska'],
#   'question': 'What is a special, small, fast look up hardware cache?'}]
# 13
# [{'answer': 'Bengal',
#   'choices': ['kolkata', 'Bengal', 'orissa', 'odisha'],
#   'question': 'Where did the first nationalistic revolutionary movement for '
#               'Indian independence emerge from?'},
#  {'answer': 'anti-colonial',
#   'choices': ['anti-british',
#               'anti-imperialist',
#               'pro-independence',
#               'anti-colonial'],
#   'question': 'What was the underlying ideology of the Indian self-rule '
#               'movement?'},
#  {'answer': '1930s',
#   'choices': ['1930s', '1960s', '1950s', '1940s'],
#   'question': 'When did the Indian self-rule movement begin?'}]
# Error in output, substring not found
# 13
# [{'answer': 'two',
#   'choices': ['six', 'five', 'four', 'two'],
#   'question': 'How many complementary definitions of vowel exist?'},
#  {'answer': 'no',
#   'choices': ['without', 'no', 'there', 'not'],
#   'question': 'Is there a significant build-up of air pressure at any point '
#               'above the glottis?'},
#  {'answer': 'consonants',
#   'choices': ['vowel', 'phonemes', 'vowels', 'consonants'],
#   'question': 'What does the English word "sh" have a constriction or closure '
#               'at some point along the vocal tract?'},
#  {'answer': 'syllabic',
#   'choices': ['alphabetic', 'syllabic', 'sonorants', 'logographic'],
#   'question': 'What is the sound that forms the peak of a syllable?'},
#  {'answer': 'semivowel',
#   'choices': ['approximant', 'semivowel', 'monophthong', 'plosive'],
#   'question': 'What is a phonetically equivalent but non-syllabic sound '
#               'called?'},
#  {'answer': 'garden',
#   'choices': ['garden', 'lawn', 'covent', 'gardening'],
#   'question': 'What does the Serbo-Croatian word vrt mean?'},
#  {'answer': 'phonological',
#   'choices': ['phonological', 'grammatical', 'syntactic', 'lexical'],
#   'question': 'The phonetic definition of "vowel" does not always match what '
#               'definition?'},
#  {'answer': 'consonants',
#   'choices': ['phonemes', 'vowel', 'consonants', 'vowels'],
#   'question': 'What do the approximants suggest that phonologically a vowel '
#               'and consonant are?'},
#  {'answer': 'bird',
#   'choices': ['avian', 'flu', 'bird', 'h5n1'],
#   'question': 'What word in a rhotic dialect has an r-colored vowel // or a '
#               'sylla'}]
# 11
# [{'answer': 'Osmosis',
#   'choices': ['distillation', 'ultrafiltration', 'Osmosis', 'desalination'],
#   'question': 'What is the spontaneous net movement of solvent molecules '
#               'through a selectively permeable membrane into a region of '
#               'higher solute concentration?'},
#  {'answer': 'solvent',
#   'choices': ['soluble', 'solvent', 'liquid', 'nontoxic'],
#   'question': 'Osmosis is a physical process in which what moves across a '
#               'selectively permeable membrane?'},
#  {'answer': 'work',
#   'choices': ['works', 'work', 'done', 'worked'],
#   'question': 'What can osmosis be made to do?'},
#  {'answer': 'semipermeable',
#   'choices': ['plasmodesmata', 'non-return', 'semipermeable', 'public/private'],
#   'question': 'What type of membranes are biological membranes?'},
#  {'answer': 'Permeability',
#   'choices': ['conductivity', 'permittivity', 'viscosity', 'Permeability'],
#   'question': 'What depends on solubility, charge, or chemistry, as well as '
#               'solute size?'},
#  {'answer': 'aquaporins',
#   'choices': ['aquaporins', 'rungfapaisarn', 'ufdots', 'jiwamol'],
#   'question': 'What are small transmembrane proteins similar to those '
#               'responsible for facilitated diffusion and ion channels?'},
#  {'answer': 'Osmosis',
#   'choices': ['ultrafiltration', 'desalination', 'Osmosis', 'distillation'],
#   'question': 'What provides the primary means by which water is transported '
#               'into and out of cells?'}]
# 15
# [{'answer': 'Vedantic',
#   'choices': ['mahayana', 'cārvāka', 'Vedantic', 'upanishadic'],
#   'question': "Vivekananda's mission was the interpretation of India's "
#               'spiritual culture, especially in what setting?'},
#  {'answer': 'India',
#   'choices': ['India', 'pakistan', 'bangladesh', 'delhi'],
#   'question': "What country was Vivekananda's spiritual ambassador in "
#               'America?'},
#  {'answer': 'Vivekananda',
#   'choices': ['ashram', 'ramakrishna', 'Vivekananda', 'sarada'],
#   'question': 'Who had a direct and intuitive experience of Reality?'},
#  {'answer': 'Ramakrishna',
#   'choices': ['sarada', 'Ramakrishna', 'belur', 'swami'],
#   'question': "Who was Vivekananda's Master?"}]

# %%
for i in range(6):
  para = getFromTextFile(f'/content/drive/MyDrive/EdRes/qg_test/test{i}.txt')
  print(f'Results for test-{i} : ')
  try:
    results = base_qaqg_nlp(para)
    print(f"PARAGRAPH-{i}")
    print(para)

    print("RESULTS")
    for result in results:
      if len(result['answer'].split()) > 1 :
        continue
      print(f"Q: {result['question']}")
      choices = [result['answer']]
      distractors = generateDistractors(result['answer'], 4)
      choices = choices + distractors[1:4]
      if len(choices) == 1:
        continue
      displayDistractors(choices)
      print(f"  Ans : {result['answer']}")
    print("")
  except Exception as e:
    print(f'Error in output, {e}')
# Out:
# Results for test-0 :
# PARAGRAPH-0
# Paging is a memory management scheme that eliminates the need for contiguous allocation of physical memory.
# This scheme permits the physical address space of a process to be non – contiguous.
# Logical Address or Virtual Address (represented in bits): An address generated by the CPU
# Logical Address Space or Virtual Address Space( represented in words or bytes): The set of all logical addresses generated by a program
# Physical Address (represented in bits): An address actually available on memory unit
# Physical Address Space (represented in words or bytes): The set of all physical addresses corresponding to the logical addresses
#
# The hardware implementation of page table can be done by using dedicated registers. But the usage of register for the page table is satisfactory only if page table is small. If page table contain large number of entries then we can use TLB(translation Look-aside buffer), a special, small, fast look up hardware cache.
#
#     The TLB is associative, high speed memory.
#     Each entry in TLB consists of two parts: a tag and a value.
#     When this memory is used, then an item is compared with all tags simultaneously.If the item is found, then corresponding value is returned.
# RESULTS
# Q: What is a memory management scheme that eliminates the need for contiguous allocation of physical memory?
#   a) telephony
#   b) pager
#   c) Paging
#   d) cellular
#   Ans : Paging
# Q: What is a special, small, fast look up hardware cache?
#   a) propiska
#   b) TLB
#   c) nobe
#   d) nke
#   Ans : TLB
#
# Results for test-1 :
# PARAGRAPH-1
# The Indian independence movement was a series of historic events with the ultimate aim of ending the British rule in India. The movement spanned from 1857 to 1947.The first nationalistic revolutionary movement for Indian independence emerged from Bengal. It later took root in the newly formed Indian National Congress with prominent moderate leaders seeking only their fundamental right to appear for Indian Civil Service examinations in British India, as well as more rights (economical in nature) for the people of the soil. The early part of the 20th century saw a more radical approach towards political self-rule proposed by leaders such as the Lal Bal Pal triumvirate, Aurobindo Ghosh and V. O. Chidambaram Pillai.[3]The last stages of the self-rule struggle from the 1920s was characterized by Congress's adoption of Mahatma Gandhi's policy of non-violence and civil disobedience, and several other campaigns.
# Nationalists like Subhas Chandra Bose, Bhagat Singh, Bagha Jatin, Surya Sen preached armed revolution to achieve self-rule.
# Poets and writers such as Rabindranath Tagore, Subramania Bharati, Bankim Chandra Chattopadhyay and Kazi Nazrul Islam used literature, poetry, and speech as a tool for political awareness.
# Feminists like Sarojini Naidu, Pritilata Waddedar, Begum Rokeya promoted the emancipation of Indian women and their participation in national politics.
# B. R. Ambedkar championed the cause of the disadvantaged sections of Indian society within the more significant self-rule movement.
# The period of the World War II saw the peak of the campaigns by the Quit India Movement led by Congress and the Indian National Army movement led by Subhas Chandra Bose with the help of Japan.
# The Indian self-rule movement was a mass-based movement that encompassed various sections of society. It also underwent a process of constant ideological evolution. Although the underlying ideology of the campaign was anti-colonial, it was supported by a vision of independent capitalist economic development coupled with a secular, democratic, republican, and civil-libertarian political structure.
# After the 1930s, the movement took on a strong socialist orientation. The work of these various movements ultimately led to the Indian Independence Act 1947, which ended the suzerainty in India, and the creation of Pakistan. India remained a Dominion of the Crown until 26 January 1950, when the Constitution of India came into force, establishing the Republic of India; Pakistan was a dominion until 1956 when it adopted its first republican constitution.
# In 1971, East Pakistan declared independence as the People's Republic of Bangladesh.
# RESULTS
# Q: Where did the first nationalistic revolutionary movement for Indian independence emerge from?
#   a) kolkata
#   b) orissa
#   c) Bengal
#   d) odisha
#   Ans : Bengal
# Q: What type of movement was the Indian self-rule movement?
# Q: What was the underlying ideology of the Indian self-rule movement?
#   a) anti-colonial
#   b) anti-british
#   c) pro-independence
#   d) anti-imperialist
#   Ans : anti-colonial
# Q: When did the Indian self-rule movement begin?
#   a) 1950s
#   b) 1960s
#   c) 1930s
#   d) 1940s
#   Ans : 1930s
#
# Results for test-2 :
# Error in output, substring not found
# Results for test-3 :
# PARAGRAPH-3
# There are two complementary definitions of vowel, one phonetic and the other phonological.
# In the phonetic definition, a vowel is a sound, such as the English "ah" /ɑː/ or "oh" /oʊ/, produced with an open vocal tract; it is median (the air escapes along the middle of the tongue), oral (at least some of the airflow must escape through the mouth), frictionless and continuant.
# There is no significant build-up of air pressure at any point above the glottis. This contrasts with consonants, such as the English "sh", which have a constriction or closure at some point along the vocal tract.
# In the phonological definition, a vowel is defined as syllabic, the sound that forms the peak of a syllable.[5] A phonetically equivalent but non-syllabic sound is a semivowel.
# In oral languages, phonetic vowels normally form the peak (nucleus) of many or all syllables, whereas consonants form the onset and (in languages that have them) coda. Some languages allow other sounds to form the nucleus of a syllable, such as the syllabic l in the English word table or the syllabic r in the Serbo-Croatian word vrt "garden".
#
# The phonetic definition of "vowel" does not always match the phonological definition.
# The approximants illustrate that both are without much of a constriction in the vocal tract (so phonetically they seem to be vowel-like), but they occur at the onset of syllables (e.g. in "yet" and "wet") which suggests that phonologically they are consonants. A similar debate arises over whether a word like bird in a rhotic dialect has an r-colored vowel /ɝ/ or a syllabic consonant /ɹ̩/.
# The American linguist Kenneth Pike (1943) suggested the terms "vocoid" for a phonetic vowel and "vowel" for a phonological vowel,[7] so using this terminology, [j] and [w] are classified as vocoids but not vowels. However, Maddieson and Emmory (1985) demonstrated from a range of languages that semivowels are produced with a narrower constriction of the vocal tract than vowels, and so may be considered consonants on that basis.
# Nonetheless, the phonetic and phonemic definitions would still conflict for the syllabic in table or the syllabic nasals in button and rhythm.
# RESULTS
# Q: How many complementary definitions of vowel exist?
#   a) four
#   b) five
#   c) six
#   d) two
#   Ans : two
# Q: Is there a significant build-up of air pressure at any point above the glottis?
#   a) not
#   b) no
#   c) there
#   d) without
#   Ans : no
# Q: What does the English word "sh" have a constriction or closure at some point along the vocal tract?
#   a) phonemes
#   b) vowels
#   c) vowel
#   d) consonants
#   Ans : consonants
# Q: What is the sound that forms the peak of a syllable?
#   a) alphabetic
#   b) logographic
#   c) syllabic
#   d) sonorants
#   Ans : syllabic
# Q: What is a phonetically equivalent but non-syllabic sound called?
#   a) plosive
#   b) approximant
#   c) monophthong
#   d) semivowel
#   Ans : semivowel
# Q: What does the Serbo-Croatian word vrt mean?
#   a) covent
#   b) gardening
#   c) lawn
#   d) garden
#   Ans : garden
# Q: The phonetic definition of "vowel" does not always match what definition?
#   a) grammatical
#   b) lexical
#   c) phonological
#   d) syntactic
#   Ans : phonological
# Q: What do the approximants suggest that phonologically a vowel and consonant are?
#   a) vowel
#   b) consonants
#   c) phonemes
#   d) vowels
#   Ans : consonants
# Q: What word in a rhotic dialect has an r-colored vowel // or a sylla
#   a) bird
#   b) flu
#   c) h5n1
#   d) avian
#   Ans : bird
#
# Results for test-4 :
# PARAGRAPH-4
# Osmosis is the spontaneous net movement of solvent molecules through a selectively permeable membrane into a region of higher solute concentration, in the direction that tends to equalize the solute concentrations on the two sides.
# It may also be used to describe a physical process in which any solvent moves across a selectively permeable membrane (permeable to the solvent, but not the solute) separating two solutions of different concentrations.
# Osmosis can be made to do work.
# Osmotic pressure is defined as the external pressure required to be applied so that there is no net movement of solvent across the membrane. Osmotic pressure is a colligative property, meaning that the osmotic pressure depends on the molar concentration of the solute but not on its identity.
#
# Osmosis is a vital process in biological systems, as biological membranes are semipermeable.
# In general, these membranes are impermeable to large and polar molecules, such as ions, proteins, and polysaccharides, while being permeable to non-polar or hydrophobic molecules like lipids as well as to small molecules like oxygen, carbon dioxide, nitrogen, and nitric oxide. Permeability depends on solubility, charge, or chemistry, as well as solute size. Water molecules travel through the plasma membrane, tonoplast membrane (vacuole) or protoplast by diffusing across the phospholipid bilayer via aquaporins (small transmembrane proteins similar to those responsible for facilitated diffusion and ion channels). Osmosis provides the primary means by which water is transported into and out of cells. The turgor pressure of a cell is largely maintained by osmosis across the cell membrane between the cell interior and its relatively hypotonic environment.
# RESULTS
# Q: What is the spontaneous net movement of solvent molecules through a selectively permeable membrane into a region of higher solute concentration?
#   a) ultrafiltration
#   b) Osmosis
#   c) desalination
#   d) distillation
#   Ans : Osmosis
# Q: Osmosis is a physical process in which what moves across a selectively permeable membrane?
#   a) nontoxic
#   b) soluble
#   c) liquid
#   d) solvent
#   Ans : solvent
# Q: What can osmosis be made to do?
#   a) works
#   b) work
#   c) worked
#   d) done
#   Ans : work
# Q: What type of membranes are biological membranes?
#   a) semipermeable
#   b) public/private
#   c) plasmodesmata
#   d) non-return
#   Ans : semipermeable
# Q: What depends on solubility, charge, or chemistry, as well as solute size?
#   a) permittivity
#   b) conductivity
#   c) viscosity
#   d) Permeability
#   Ans : Permeability
# Q: What are small transmembrane proteins similar to those responsible for facilitated diffusion and ion channels?
#   a) ufdots
#   b) rungfapaisarn
#   c) aquaporins
#   d) jiwamol
#   Ans : aquaporins
# Q: What provides the primary means by which water is transported into and out of cells?
#   a) ultrafiltration
#   b) Osmosis
#   c) distillation
#   d) desalination
#   Ans : Osmosis
#
# Results for test-5 :
# PARAGRAPH-5
# Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.
#
# In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.
#
# In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.
#
# The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soulstirring language of poetry.
#
# The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth; and this choice has endeared him to people in the West, Americans in particular.
#
# In the course of a short life of thirty-nine years (1863-1902), of which only ten were devoted to public activities-and those, too, in the midst of acute physical suffering-he left for posterity his four classics: Jnana-Yoga, Bhakti-Yoga, Karma-Yoga, and Raja-Yoga, all of which are outstanding treatises on Hindu philosophy. In addition, he delivered innumerable lectures, wrote inspired letters in his own hand to his many friends and disciples, composed numerous poems, and acted as spiritual guide to the many seekers, who came to him for instruction. He also organized the Ramakrishna Order of monks, which is the most outstanding religious organization of modern India. It is devoted to the propagation of the Hindu spiritual culture not only in the Swami's native land, but also in America and in other parts of the world.
#
# Swami Vivekananda once spoke of himself as a "condensed India." His life and teachings are of inestimable value to the West for an understanding of the mind of Asia. William James, the Harvard philosopher, called the Swami the "paragon of Vedantists." Max Muller and Paul Deussen, the famous Orientalists of the nineteenth century, held him in genuine respect and affection. "His words," writes Romain Rolland, "are great music, phrases in the style of Beethoven, stirring rhythms like the march of Handel choruses. I cannot touch these sayings of his, scattered as they are through the pages of books, at thirty years' distance, without receiving a thrill through my body like an electric shock. And what shocks, what transports, must have been produced when in burning words they issued from the lips of the hero!''
# RESULTS
# Q: Vivekananda's mission was the interpretation of India's spiritual culture, especially in what setting?
#   a) Vedantic
#   b) mahayana
#   c) upanishadic
#   d) cārvāka
#   Ans : Vedantic
# Q: What country was Vivekananda's spiritual ambassador in America?
#   a) bangladesh
#   b) delhi
#   c) pakistan
#   d) India
#   Ans : India
# Q: Who had a direct and intuitive experience of Reality?
#   a) sarada
#   b) ashram
#   c) Vivekananda
#   d) ramakrishna
#   Ans : Vivekananda
# Q: Who was Vivekananda's Master?
#   a) belur
#   b) Ramakrishna
#   c) sarada
#   d) swami
#   Ans : Ramakrishna

# %% [markdown]
# ## Test and Play Area

# %%
#@title Question Generator

paragraph = "Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth; and this choice has endeared him to people in the West, Americans in particular.  In the course of a short life of thirty-nine years (1863-1902), of which only ten were devoted to public activities-and those, too, in the midst of acute physical suffering-he left for posterity his four classics: Jnana-Yoga, Bhakti-Yoga, Karma-Yoga, and Raja-Yoga, all of which are outstanding treatises on Hindu philosophy. In addition, he delivered innumerable lectures, wrote inspired letters in his own hand to his many friends and disciples, composed numerous poems, and acted as spiritual guide to the many seekers, who came to him for instruction. He also organized the Ramakrishna Order of monks, which is the most outstanding religious organization of modern India. It is devoted to the propagation of the Hindu spiritual culture not only in the Swami's native land, but also in America and in other parts of the world.  Swami Vivekananda once spoke of himself as a \"condensed India.\" His life and teachings are of inestimable value to the West for an understanding of the mind of Asia. William James, the Harvard philosopher, called the Swami the \"paragon of Vedantists.\" Max Muller and Paul Deussen, the famous Orientalists of the nineteenth century, held him in genuine respect and affection. \"His words,\" writes Romain Rolland, \"are great music, phrases in the style of Beethoven, stirring rhythms like the march of Handel choruses. I cannot touch these sayings of his, scattered as they are through the pages of books, at thirty years' distance, without receiving a thrill through my body like an electric shock. And what shocks, what transports, must have been produced when in burning words they issued from the lips of the hero!''  In 1881 Narendra first met Ramakrishna, who became his spiritual focus after his own father had died in 1884. Narendra's first introduction to Ramakrishna occurred in a literature class at General Assembly's Institution when he heard Professor William Hastie lecturing on William Wordsworth's poem, The Excursion. While explaining the word \"trance\" in the poem, Hastie suggested that his students visit Ramakrishna of Dakshineswar to understand the true meaning of trance. This prompted some of his students (including Narendra) to visit Ramakrishna Ramakrishna, guru of Vivekananda  Vivekananda in Cossipore 1886 They probably first met personally in November 1881 though Narendra did not consider this their first meeting, and neither man mentioned this meeting later. At this time, Narendra was preparing for his upcoming F. A. examination, when Ram Chandra Datta accompanied him to Surendra Nath Mitra's, house where Ramakrishna was invited to deliver a lecture.According to Paranjape, at this meeting Ramakrishna asked young Narendra to sing. Impressed by his singing talent, he asked Narendra to come to Dakshineshwar. In late 1881 or early 1882, Narendra went to Dakshineswar with two friends and met Ramakrishna. This meeting proved to be a turning point in his life.Although he did not initially accept Ramakrishna as his teacher and rebelled against his ideas, he was attracted by his personality and began to frequently visit him at Dakshineswar. He initially saw Ramakrishna's ecstasies and visions as \"mere figments of imagination\" and \"hallucinations\".As a member of Brahmo Samaj, he opposed idol worship, polytheism and Ramakrishna's worship of Kali.He even rejected the Advaita Vedanta of \"identity with the absolute\" as blasphemy and madness, and often ridiculed the idea. Narendra tested Ramakrishna, who faced his arguments patiently: \"Try to see the truth from all angles\", he replied. Narendra's father's sudden death in 1884 left the family bankrupt; creditors began demanding the repayment of loans, and relatives threatened to evict the family from their ancestral home. Narendra, once a son of a well-to-do family, became one of the poorest students in his college.He unsuccessfully tried to find work and questioned God's existence, but found solace in Ramakrishna and his visits to Dakshineswar increased. One day, Narendra requested Ramakrishna to pray to goddess Kali for their family's financial welfare. Ramakrishna suggested him to go to the temple himself and pray. Following Ramakrishna's suggestion, he went to the temple thrice, but failed to pray for any kind of worldly necessities and ultimately prayed for true knowledge and devotion from the goddess.Narendra gradually grew ready to renounce everything for the sake of realising God, and accepted Ramakrishna as his Guru. In 1885, Ramakrishna developed throat cancer, and was transferred to Calcutta and (later) to a garden house in Cossipore. Narendra and Ramakrishna's other disciples took care of him during his last days, and Narendra's spiritual education continued. At Cossipore, he experienced Nirvikalpa samadhi.Narendra and several other disciples received ochre robes from Ramakrishna, forming his first monastic order.He was taught that service to men was the most effective worship of God. Ramakrishna asked him to care for the other monastic disciples, and in turn asked them to see Narendra as their leader.Ramakrishna died in the early-morning hours of 16 August 1886 in Cossipore." #@param {type:"string"}

results = base_qaqg_nlp(paragraph)

# print("RESULTS")
# for result in results:
#   print(f"Q: {result['question']}")
#   print(f"A: {result['answer']}")
#   print()
try:
  print("RESULTS")
  for result in results:
    if len(result['answer'].split()) > 1 :
      continue
    print(f"Q: {result['question']}")
    choices = [result['answer']]
    distractors = generateDistractors(result['answer'], 4)
    choices = choices + distractors[1:4]
    if len(choices) == 1:
      continue
    displayDistractors(choices)
    print(f"  Ans : {result['answer']}")
except:
  print('try another')
# Out:
# RESULTS
# Q: Vivekananda's mission was the interpretation of India's spiritual culture, especially in what setting?
#   a) Vedantic
#   b) cārvāka
#   c) mahayana
#   d) upanishadic
#   Ans : Vedantic
# Q: What country was Vivekananda's spiritual ambassador in America?
#   a) bangladesh
#   b) delhi
#   c) pakistan
#   d) India
#   Ans : India
# Q: Who had a direct and intuitive experience of Reality?
#   a) sarada
#   b) Vivekananda
#   c) ramakrishna
#   d) ashram
#   Ans : Vivekananda
# Q: Who was Swami Vivekananda's Master?
#   a) belur
#   b) sarada
#   c) swami
#   d) Ramakrishna
#   Ans : Ramakrishna

# %%
test_para = """Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth; and this choice has endeared him to people in the West, Americans in particular.  In the course of a short life of thirty-nine years (1863-1902), of which only ten were devoted to public activities-and those, too, in the midst of acute physical suffering-he left for posterity his four classics: Jnana-Yoga, Bhakti-Yoga, Karma-Yoga, and Raja-Yoga, all of which are outstanding treatises on Hindu philosophy. In addition, he delivered innumerable lectures, wrote inspired letters in his own hand to his many friends and disciples, composed numerous poems, and acted as spiritual guide to the many seekers, who came to him for instruction. He also organized the Ramakrishna Order of monks, which is the most outstanding religious organization of modern India. It is devoted to the propagation of the Hindu spiritual culture not only in the Swami's native land, but also in America and in other parts of the world.  Swami Vivekananda once spoke of himself as a "condensed India." His life and teachings are of inestimable value to the West for an understanding of the mind of Asia. William James, the Harvard philosopher, called the Swami the "paragon of Vedantists." Max Muller and Paul Deussen, the famous Orientalists of the nineteenth century, held him in genuine respect and affection. "His words," writes Romain Rolland, "are great music, phrases in the style of Beethoven, stirring rhythms like the march of Handel choruses. I cannot touch these sayings of his, scattered as they are through the pages of books, at thirty years' distance, without receiving a thrill through my body like an electric shock. And what shocks, what transports, must have been produced when in burning words they issued from the lips of the hero!''  In 1881 Narendra first met Ramakrishna, who became his spiritual focus after his own father had died in 1884. Narendra's first introduction to Ramakrishna occurred in a literature class at General Assembly's Institution when he heard Professor William Hastie lecturing on William Wordsworth's poem, The Excursion. While explaining the word "trance" in the poem, Hastie suggested that his students visit Ramakrishna of Dakshineswar to understand the true meaning of trance. This prompted some of his students (including Narendra) to visit Ramakrishna Ramakrishna, guru of Vivekananda  Vivekananda in Cossipore 1886 They probably first met personally in November 1881 though Narendra did not consider this their first meeting, and neither man mentioned this meeting later. At this time, Narendra was preparing for his upcoming F. A. examination, when Ram Chandra Datta accompanied him to Surendra Nath Mitra's, house where Ramakrishna was invited to deliver a lecture.According to Paranjape, at this meeting Ramakrishna asked young Narendra to sing. Impressed by his singing talent, he asked Narendra to come to Dakshineshwar. In late 1881 or early 1882, Narendra went to Dakshineswar with two friends and met Ramakrishna. This meeting proved to be a turning point in his life.Although he did not initially accept Ramakrishna as his teacher and rebelled against his ideas, he was attracted by his personality and began to frequently visit him at Dakshineswar. He initially saw Ramakrishna's ecstasies and visions as "mere figments of imagination" and "hallucinations".As a member of Brahmo Samaj, he opposed idol worship, polytheism and Ramakrishna's worship of Kali.He even rejected the Advaita Vedanta of "identity with the absolute" as blasphemy and madness, and often ridiculed the idea. Narendra tested Ramakrishna, who faced his arguments patiently: "Try to see the truth from all angles", he replied. Narendra's father's sudden death in 1884 left the family bankrupt; creditors began demanding the repayment of loans, and relatives threatened to evict the family from their ancestral home. Narendra, once a son of a well-to-do family, became one of the poorest students in his college.He unsuccessfully tried to find work and questioned God's existence, but found solace in Ramakrishna and his visits to Dakshineswar increased. One day, Narendra requested Ramakrishna to pray to goddess Kali for their family's financial welfare. Ramakrishna suggested him to go to the temple himself and pray. Following Ramakrishna's suggestion, he went to the temple thrice, but failed to pray for any kind of worldly necessities and ultimately prayed for true knowledge and devotion from the goddess.Narendra gradually grew ready to renounce everything for the sake of realising God, and accepted Ramakrishna as his Guru. In 1885, Ramakrishna developed throat cancer, and was transferred to Calcutta and (later) to a garden house in Cossipore. Narendra and Ramakrishna's other disciples took care of him during his last days, and Narendra's spiritual education continued. At Cossipore, he experienced Nirvikalpa samadhi.Narendra and several other disciples received ochre robes from Ramakrishna, forming his first monastic order.He was taught that service to men was the most effective worship of God. Ramakrishna asked him to care for the other monastic disciples, and in turn asked them to see Narendra as their leader.Ramakrishna died in the early-morning hours of 16 August 1886 in Cossipore."""

# %% [markdown]
# ## Text Summarization

# %% [markdown]
# ### Using GPT - 2

# %%
# Importing model and tokenizer
from transformers import GPT2Tokenizer,GPT2LMHeadModel

# Instantiating the model and tokenizer with gpt-2
tokenizer=GPT2Tokenizer.from_pretrained('gpt2')
model=GPT2LMHeadModel.from_pretrained('gpt2')

# Encoding text to get input ids & pass them to model.generate()
inputs=tokenizer.batch_encode_plus([test_para],return_tensors='pt',max_length=512)
summary_ids=model.generate(inputs['input_ids'],early_stopping=True)

# Decoding and printing summary
GPT_summary=tokenizer.decode(summary_ids[0],skip_special_tokens=True)
print(GPT_summary)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1042301.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=665.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=548118077.0, style=ProgressStyle(descri…
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.attn.masked_bias', 'h.1.attn.masked_bias', 'h.2.attn.masked_bias', 'h.3.attn.masked_bias', 'h.4.attn.masked_bias', 'h.5.attn.masked_bias', 'h.6.attn.masked_bias', 'h.7.attn.masked_bias', 'h.8.attn.masked_bias', 'h.9.attn.masked_bias', 'h.10.attn.masked_bias', 'h.11.attn.masked_bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth

# %%
print(GPT_summary)
# Out:
# Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth

# %% [markdown]
# ### Using T5

# %%
import torch
import json
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config
use_cuda = True
model = T5ForConditionalGeneration.from_pretrained('t5-base')
tokenizer = T5Tokenizer.from_pretrained('t5-base')
device = torch.device('cpu')
# device = "cuda" if torch.cuda.is_available() and use_cuda else "cpu"

preprocess_text = test_para.strip().replace("\n","")
t5_prepared_Text = "summarize: "+ test_para
print ("original text preprocessed: \n", test_para)

tokenized_text = tokenizer.encode(t5_prepared_Text, return_tensors="pt", max_length=512).to(device)


# summmarize
summary_ids = model.generate(tokenized_text,
                                    num_beams=4,
                                    no_repeat_ngram_size=2,
                                    min_length=30,
                                    max_length=100,
                                    num_return_sequences=3,
                                    early_stopping=True)

output = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print ("\n\nSummarized text: \n",output)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1199.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691430.0, style=ProgressStyle(descri…
# Some weights of T5ForConditionalGeneration were not initialized from the model checkpoint at t5-base and are newly initialized: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# original text preprocessed:
#  Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth; and this choice has endeared him to people in the West, Americans in particular.  In the course of a short life of thirty-nine years (1863-1902), of which only ten were devoted to public activities-and those, too, in the midst of acute physical suffering-he left for posterity his four classics: Jnana-Yoga, Bhakti-Yoga, Karma-Yoga, and Raja-Yoga, all of which are outstanding treatises on Hindu philosophy. In addition, he delivered innumerable lectures, wrote inspired letters in his own hand to his many friends and disciples, composed numerous poems, and acted as spiritual guide to the many seekers, who came to him for instruction. He also organized the Ramakrishna Order of monks, which is the most outstanding religious organization of modern India. It is devoted to the propagation of the Hindu spiritual culture not only in the Swami's native land, but also in America and in other parts of the world.  Swami Vivekananda once spoke of himself as a "condensed India." His life and teachings are of inestimable value to the West for an understanding of the mind of Asia. William James, the Harvard philosopher, called the Swami the "paragon of Vedantists." Max Muller and Paul Deussen, the famous Orientalists of the nineteenth century, held him in genuine respect and affection. "His words," writes Romain Rolland, "are great music, phrases in the style of Beethoven, stirring rhythms like  ...
#
#
# Summarized text:
#  the unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893. he represented Hinduism and was regarded as a patriot saint of modern india and an inspirer of her dormant national consciousness. many political leaders of india have publicly acknowledged their indebtedness to Swami Vivekananda.

# %%
t5_prepared_Text = "question: "+ test_para
print ("original text preprocessed: \n", test_para)

tokenized_text = tokenizer.encode(t5_prepared_Text, return_tensors="pt", max_length=512).to(device)

# summmarize
summary_ids = model.generate(tokenized_text,
                                    num_beams=4,
                                    no_repeat_ngram_size=2,
                                    min_length=30,
                                    max_length=100,
                                    early_stopping=True)

output = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print ("\n\nSummarized text: \n",output)
# Out:
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# original text preprocessed:
#  Swami Vivekananda's inspiring personality was well known both in India and in America during the last decade of the nineteenth century and the first decade of the twentieth. The unknown monk of India suddenly leapt into fame at the Parliament of Religions held in Chicago in 1893, at which he represented Hinduism. His vast knowledge of Eastern and Western culture as well as his deep spiritual insight, fervid eloquence, brilliant conversation, broad human sympathy, colourful personality, and handsome figure made an irresistible appeal to the many types of Americans who came in contact with him. People who saw or heard Vivekananda even once still cherish his memory after a lapse of more than half a century.  In America Vivekananda's mission was the interpretation of India's spiritual culture, especially in its Vedantic setting. He also tried to enrich the religious consciousness of the Americans through the rational and humanistic teachings of the Vedanta philosophy. In America he became India's spiritual ambassador and pleaded eloquently for better understanding between India and the New World in order to create a healthy synthesis of East and West, of religion and science.  In his own motherland Vivekananda is regarded as the patriot saint of modern India and an inspirer of her dormant national consciousness, To the Hindus he preached the ideal of a strength-giving and man-making religion. Service to man as the visible manifestation of the Godhead was the special form of worship he advocated for the Indians, devoted as they were to the rituals and myths of their ancient faith. Many political leaders of India have publicly acknowledged their indebtedness to Swami Vivekananda.  The Swami's mission was both national and international. A lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence. A mystic of the highest order, Vivekananda had a direct and intuitive experience of Reality. He derived his ideas from that unfailing source of wisdom and often presented them in the soul stirring language of poetry.  The natural tendency of Vivekananda's mind, like that of his Master, Ramakrishna, was to soar above the world and forget itself in contemplation of the Absolute. But another part of his personality bled at the sight of human suffering in East and West alike. It might appear that his mind seldom found a point of rest in its oscillation between contemplation of God and service to man. Be that as it may, he chose, in obedience to a higher call, service to man as his mission on earth; and this choice has endeared him to people in the West, Americans in particular.  In the course of a short life of thirty-nine years (1863-1902), of which only ten were devoted to public activities-and those, too, in the midst of acute physical suffering-he left for posterity his four classics: Jnana-Yoga, Bhakti-Yoga, Karma-Yoga, and Raja-Yoga, all of which are outstanding treatises on Hindu philosophy. In addition, he delivered innumerable lectures, wrote inspired letters in his own hand to his many friends and disciples, composed numerous poems, and acted as spiritual guide to the many seekers, who came to him for instruction. He also organized the Ramakrishna Order of monks, which is the most outstanding religious organization of modern India. It is devoted to the propagation of the Hindu spiritual culture not only in the Swami's native land, but also in America and in other parts of the world.  Swami Vivekananda once spoke of himself as a "condensed India." His life and teachings are of inestimable value to the West for an understanding of the mind of Asia. William James, the Harvard philosopher, called the Swami the "paragon of Vedantists." Max Muller and Paul Deussen, the famous Orientalists of the nineteenth century, held him in genuine respect and affection. "His words," writes Romain Rolland, "are great music, phrases in the style of Beethoven, stirring rhythms like  ...
#
#
# Summarized text:
#  a lover of mankind, he strove to promote peace and human brotherhood on the spiritual foundation of the Vedantic Oneness of existence.

# %% [markdown]
# ## C-Profiling : Attempt to find the bottlenecks

# %%
import cProfile
import pstats
from functools import wraps


def profile(output_file=None, sort_by='cumulative', lines_to_print=None, strip_dirs=False):
    """A time profiler decorator.
    Inspired by and modified the profile decorator of Giampaolo Rodola:
    http://code.activestate.com/recipes/577817-profile-decorator/
    Args:
        output_file: str or None. Default is None
            Path of the output file. If only name of the file is given, it's
            saved in the current directory.
            If it's None, the name of the decorated function is used.
        sort_by: str or SortKey enum or tuple/list of str/SortKey enum
            Sorting criteria for the Stats object.
            For a list of valid string and SortKey refer to:
            https://docs.python.org/3/library/profile.html#pstats.Stats.sort_stats
        lines_to_print: int or None
            Number of lines to print. Default (None) is for all the lines.
            This is useful in reducing the size of the printout, especially
            that sorting by 'cumulative', the time consuming operations
            are printed toward the top of the file.
        strip_dirs: bool
            Whether to remove the leading path info from file names.
            This is also useful in reducing the size of the printout
    Returns:
        Profile of the decorated function
    """

    def inner(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            _output_file = output_file or func.__name__ + '.prof'
            pr = cProfile.Profile()
            pr.enable()
            retval = func(*args, **kwargs)
            pr.disable()
            pr.dump_stats(_output_file)

            with open(_output_file, 'w') as f:
                ps = pstats.Stats(pr, stream=f)
                if strip_dirs:
                    ps.strip_dirs()
                if isinstance(sort_by, (tuple, list)):
                    ps.sort_stats(*sort_by)
                else:
                    ps.sort_stats(sort_by)
                ps.print_stats(lines_to_print)
            return retval

        return wrapper

    return inner

# %%
import cProfile
import io
import pstats
def profile2(func):
    def wrapper(*args, **kwargs):
        pr = cProfile.Profile()
        pr.enable()
        retval = func(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'tottime' #'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval

    return wrapper

# %%
# @profile(sort_by='cumulative', lines_to_print=100, strip_dirs=True)
@profile2
def get_results(para):
  results = base_qaqg_nlp(paragraph)
  try:
    print("RESULTS")
    for result in results:
      if len(result['answer'].split()) > 1 :
        continue
      print(f"Q: {result['question']}")
      choices = [result['answer']]
      distractors = generateDistractors(result['answer'], 4)
      choices = choices + distractors[1:4]
      if len(choices) == 1:
        continue
      displayDistractors(choices)
      print(f"  Ans : {result['answer']}")
  except:
    print('try another')

# %%
# import cProfile
# cProfile.run("get_results(test_para)")
get_results(test_para)
# Out:
# RESULTS
# Q: Vivekananda's mission was the interpretation of India's spiritual culture, especially in what setting?
# Q: What country was Vivekananda's spiritual ambassador in America?
# Q: Who had a direct and intuitive experience of Reality?
# Q: Who was Swami Vivekananda's Master?
#          2287269 function calls (2270566 primitive calls) in 11.455 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1954    6.227    0.003    6.227    0.003 {method 'to' of 'torch._C._TensorBase' objects}
#      1641    1.483    0.001    1.483    0.001 {method 'item' of 'torch._C._TensorBase' objects}
#         1    1.251    1.251    1.616    1.616 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1255(_generate_no_beam_search)
#    198534    0.193    0.000    0.647    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_t5.py:175(_convert_token_to_id)
#      4266    0.157    0.000    0.157    0.000 {built-in method torch._C._nn.linear}
#      1604    0.129    0.000    0.264    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:155(forward)
#  11910/44    0.110    0.000    3.245    0.074 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:866(_call_impl)
#       188    0.103    0.001    0.103    0.001 {built-in method sentencepiece._sentencepiece.SentencePieceProcessor_EncodeAsPieces}
#    198660    0.096    0.000    0.743    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:391(_convert_token_to_id_with_added_voc)
#       787    0.085    0.000    0.850    0.001 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:376(convert_tokens_to_ids)
#         1    0.079    0.079    4.444    4.444 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1355(_generate_beam_search)
#      1032    0.068    0.000    0.068    0.000 {built-in method einsum}
#      1032    0.067    0.000    0.744    0.001 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:294(forward)
#    126534    0.061    0.000    0.061    0.000 {built-in method sentencepiece._sentencepiece.SentencePieceProcessor_PieceToId}
#      1604    0.058    0.000    0.058    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#        97    0.057    0.001    0.057    0.001 {method 'new' of 'torch._C._TensorBase' objects}
#    127335    0.052    0.000    0.199    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:497(_batched_func)
#    127335    0.048    0.000    0.147    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:492(_func)
#     72000    0.045    0.000    0.090    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_t5.py:139(vocab_size)
#      1604    0.043    0.000    0.043    0.000 {method 'mean' of 'torch._C._TensorBase' objects}
#      1032    0.043    0.000    0.043    0.000 {built-in method matmul}
#        63    0.043    0.001    0.212    0.003 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:337(split_on_tokens)
#     72002    0.039    0.000    0.055    0.000 /usr/lib/python3.7/re.py:273(_compile)
#     72000    0.038    0.000    0.121    0.000 /usr/lib/python3.7/re.py:172(match)
#    126534    0.036    0.000    0.097    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:134(PieceToId)
#    198538    0.034    0.000    0.034    0.000 {method 'startswith' of 'str' objects}
#        63    0.032    0.001    0.352    0.006 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:837(convert_ids_to_tokens)
#      1245    0.030    0.000    0.030    0.000 {built-in method floor_divide}
#      1002    0.029    0.000    0.029    0.000 {built-in method cat}
#     16990    0.028    0.000    0.064    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:284(split_on_token)
#     17154    0.028    0.000    0.028    0.000 {method 'split' of 'str' objects}
#     72198    0.027    0.000    0.027    0.000 {method 'match' of 're.Pattern' objects}
#      1604    0.026    0.000    0.026    0.000 {built-in method sqrt}
#     23480    0.025    0.000    0.025    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:934(__getattr__)
#     73602    0.023    0.000    0.023    0.000 {built-in method sentencepiece._sentencepiece.SentencePieceProcessor_GetPieceSize}
#     73602    0.023    0.000    0.046    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:131(GetPieceSize)
#    101591    0.022    0.000    0.022    0.000 {built-in method builtins.isinstance}
#    201918    0.022    0.000    0.022    0.000 {method 'append' of 'list' objects}
#      1032    0.021    0.000    0.021    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#       528    0.020    0.000    0.538    0.001 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:405(forward)
#       504    0.019    0.000    0.470    0.001 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:438(forward)
#        86    0.018    0.000    0.045    0.001 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:231(_relative_position_bucket)
#       528    0.017    0.000    0.216    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:187(forward)
#      1490    0.017    0.000    0.017    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#     12548    0.015    0.000    0.015    0.000 {built-in method torch._C._get_tracing_state}
#      3250    0.015    0.000    0.015    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#      4266    0.014    0.000    0.185    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py:93(forward)
#      3168    0.014    0.000    0.014    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
# 97077/92783    0.014    0.000    0.016    0.000 {built-in method builtins.len}
#     72148    0.013    0.000    0.013    0.000 {method 'group' of 're.Match' objects}
#       720    0.013    0.000    0.013    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:908(<listcomp>)
#       528    0.013    0.000    1.277    0.002 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:479(forward)
#      3208    0.013    0.000    0.029    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1059(dropout)
#        86    0.012    0.000    0.012    0.000 {built-in method log}
#       528    0.012    0.000    0.012    0.000 {built-in method relu}
#      3208    0.012    0.000    0.012    0.000 {built-in method dropout}
#       783    0.012    0.000    0.019    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:911(all_special_tokens_extended)
#       528    0.008    0.000    0.092    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:172(forward)
#       299    0.008    0.000    0.008    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#      4266    0.008    0.000    0.166    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1737(linear)
#        86    0.007    0.000    0.273    0.003 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:279(compute_bias)
#       638    0.007    0.000    0.007    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#     47684    0.007    0.000    0.007    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        44    0.007    0.000    3.238    0.074 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:655(forward)
#        44    0.007    0.000    0.016    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:187(get_extended_attention_mask)
#      1560    0.006    0.000    0.010    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:152(_get_abs_string_index)
#      1032    0.005    0.000    0.076    0.000 /usr/local/lib/python3.7/dist-packages/torch/functional.py:295(einsum)
#       130    0.005    0.000    0.005    0.000 {built-in method embedding}
#      2136    0.005    0.000    0.025    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:330(shape)
#       216    0.005    0.000    0.005    0.000 {built-in method arange}
#     10504    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#      2176    0.005    0.000    0.024    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/dropout.py:57(forward)
#      1118    0.004    0.000    0.004    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#        31    0.004    0.000    0.004    0.000 {built-in method topk}
#      4240    0.004    0.000    0.006    0.000 /usr/local/lib/python3.7/dist-packages/torch/_VF.py:25(__getattr__)
#      1032    0.004    0.000    0.013    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:334(unshape)
#      1032    0.003    0.000    0.003    0.000 {method 'type_as' of 'torch._C._TensorBase' objects}
#       783    0.003    0.000    0.006    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:886(special_tokens_map_extended)
#        97    0.003    0.000    0.003    0.000 {built-in method rsub}
#      1560    0.003    0.000    0.014    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:161(__getitem__)
#        86    0.003    0.000    0.003    0.000 {built-in method min}
#         4    0.003    0.001    0.003    0.001 {built-in method tensor}
#        42    0.003    0.000    3.107    0.074 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:1022(forward)
#      1642    0.003    0.000    0.003    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#         2    0.003    0.001    0.647    0.323 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:476(_batch_encode_plus)
#        98    0.003    0.000    0.003    0.000 {method 'clone' of 'torch._C._TensorBase' objects}
#        86    0.002    0.000    0.002    0.000 {built-in method where}
#        44    0.002    0.000    0.002    0.000 {method 'repeat' of 'torch._C._TensorBase' objects}
#        42    0.002    0.000    0.007    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:161(invert_attention_mask)
#     17055    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#      1245    0.002    0.000    0.033    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:24(wrapped)
#        84    0.002    0.000    0.002    0.000 {built-in method max}
#      1032    0.002    0.000    0.023    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1553(softmax)
#        31    0.002    0.000    0.018    0.001 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:1173(_reorder_cache)
#       638    0.002    0.000    0.010    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:575(__iter__)
#        63    0.002    0.000    0.503    0.008 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:872(decode)
#      3652    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:182(__len__)
#       485    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#        86    0.001    0.000    0.001    0.000 {built-in method full_like}
#         1    0.001    0.001    0.006    0.006 <ipython-input-5-8b5562cd4f4b>:111(_prepare_inputs_for_ans_extraction)
#      5898    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_unary}
#        49    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1287(_slices_from_text)
#        63    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:734(truncate_sequences)
#      1245    0.001    0.000    0.031    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:557(__floordiv__)
#       801    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_t5.py:183(_convert_id_to_token)
#      4363    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_variadic}
#      1034    0.001    0.000    0.001    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#       720    0.001    0.000    0.461    0.001 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:925(all_special_ids)
#       720    0.001    0.000    0.031    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:901(all_special_tokens)
#       344    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1227(_named_members)
#        84    0.001    0.000    0.001    0.000 {built-in method zeros_like}
#       188    0.001    0.000    0.104    0.001 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:98(EncodeAsPieces)
#        78    0.001    0.000    0.001    0.000 {built-in method sentencepiece._sentencepiece.SentencePieceProcessor_DecodePieces}
#        63    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:269(<genexpr>)
#       528    0.001    0.000    0.013    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1195(relu)
#        31    0.001    0.000    0.001    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#        86    0.001    0.000    0.001    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#   860/516    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1394(named_modules)
#        42    0.001    0.000    0.001    0.000 {built-in method ones}
#       440    0.001    0.000    0.106    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:357(<genexpr>)
#       801    0.001    0.000    0.001    0.000 {built-in method sentencepiece._sentencepiece.SentencePieceProcessor_IdToPiece}
#       130    0.001    0.000    0.001    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#       344    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1240(parameters)
#         2    0.001    0.000    0.001    0.000 {built-in method abs}
#      2277    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function}
#       102    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1736(add)
#         2    0.001    0.000    0.648    0.324 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1762(batch_encode_plus)
#       170    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:143(dtype)
#         2    0.001    0.000   10.296    5.148 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:871(generate)
#       130    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/sparse.py:155(forward)
#        63    0.001    0.000    0.216    0.003 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:256(tokenize)
#         2    0.001    0.000    0.007    0.003 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:559(_batch_prepare_for_model)
#       642    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1730(__len__)
#      1560    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        11    0.000    0.000    0.000    0.000 {built-in method argmax}
#       286    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1750(is_done)
#       929    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#        49    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1332(text_contains_sentbreak)
#        22    0.000    0.000    0.000    0.000 {method 'long' of 'torch._C._TensorBase' objects}
#        63    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:623(_prepare_for_model)
#       188    0.000    0.000    0.105    0.001 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_t5.py:166(_tokenize)
#       117    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:568(__len__)
#       153    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:537(_tokenize_words)
#        63    0.000    0.000    0.637    0.010 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:503(get_input_ids)
#       104    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:390(__init__)
#       344    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1264(named_parameters)
#       801    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:137(IdToPiece)
#        11    0.000    0.000    0.000    0.000 {method 'masked_fill_' of 'torch._C._TensorBase' objects}
#       801    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:330(piece_size)
#        97    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:525(__rsub__)
#       344    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/tensor.py:593(__hash__)
#       785    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       104    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:585(_first_pass_annotation)
#        86    0.000    0.000    0.000    0.000 {built-in method math.log}
#        31    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1537(<listcomp>)
#        49    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#       344    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1285(<lambda>)
#      2431    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        69    0.000    0.000    0.000    0.000 /usr/lib/python3.7/_collections_abc.py:824(update)
#        31    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1538(<listcomp>)
#       130    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1828(embedding)
#        63    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1963(_pad)
#   271/221    0.000    0.000    0.005    0.000 {built-in method builtins.next}
#        11    0.000    0.000    0.000    0.000 {method 'bool' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1863(pad)
#        69    0.000    0.000    0.001    0.000 /usr/lib/python3.7/collections/__init__.py:1000(__init__)
#       785    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       465    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        69    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:145(__init__)
#        11    0.000    0.000    0.000    0.000 {method 'mul' of 'torch._C._TensorBase' objects}
#        31    0.000    0.000    0.000    0.000 {method 'expand_as' of 'torch._C._TensorBase' objects}
#        31    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1539(<listcomp>)
#        11    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py:438(send)
#    198/49    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:305(_pair_iter)
#       632    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       149    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1466(_annotate_second_pass)
#       516    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        11    0.000    0.000    0.000    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#       100    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1476(_second_pass_annotation)
#        49    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1302(_realign_boundaries)
#        44    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:231(get_head_mask)
#         6    0.000    0.000    0.063    0.010 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1563(<genexpr>)
#       124    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#       105    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       153    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:564(_annotate_first_pass)
#        63    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2081(clean_up_tokenization)
#        63    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:804(create_token_type_ids_from_sequences)
#       104    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:413(_get_type)
#       618    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       193    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       516    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.016    0.016 <ipython-input-5-8b5562cd4f4b>:87(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-8b5562cd4f4b>:129(_prepare_inputs_for_qg_from_answers_hl)
#        81    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 {built-in method zeros}
#         3    0.000    0.000    0.000    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#       189    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#        42    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:810(_use_cache)
#         1    0.000    0.000   11.454   11.454 <ipython-input-5-8b5562cd4f4b>:46(__call__)
#       344    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        78    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_t5.py:191(convert_tokens_to_string)
#         1    0.000    0.000    0.487    0.487 <ipython-input-5-8b5562cd4f4b>:74(<listcomp>)
#        50    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:417(type_no_period)
#         2    0.000    0.000    0.000    0.000 {built-in method full}
#        44    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:186(__iter__)
#        42    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:1160(prepare_inputs_for_generation)
#        31    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1651(log_softmax)
#        11    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py:195(schedule)
#        69    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:476(convert_to_tensors)
#        79    0.000    0.000    0.000    0.000 /usr/lib/python3.7/collections/__init__.py:1028(__setitem__)
#       154    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       103    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:454(is_ellipsis)
#         2    0.000    0.000   10.296    5.148 /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py:24(decorate_context)
#       205    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    5.396    5.396 <ipython-input-5-8b5562cd4f4b>:77(_extract_answers)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py:382(write)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1433(_get_padding_truncation_strategies)
#       260    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000   11.455   11.455 <ipython-input-27-30fb5c161a3d>:2(get_results)
#        69    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        63    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:237(num_special_tokens_to_add)
#        49    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:260(word_tokenize)
#        49    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1368(_annotate_tokens)
#        42    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:828(postprocess_next_token_scores)
#        65    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:205(items)
#        15    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1744(<listcomp>)
#        78    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/dist-packages/sentencepiece/__init__.py:116(DecodePieces)
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        44    0.000    0.000    0.000    0.000 {method 'start' of 're.Match' objects}
#        48    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:464(is_initial)
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1276(<listcomp>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1558(_ortho_heuristic)
#         4    0.000    0.000    0.000    0.000 <ipython-input-9-02cf05485b4b>:1(generateDistractors)
#         1    0.000    0.000    0.000    0.000 {method 'min' of 'torch._C._TensorBase' objects}
#        69    0.000    0.000    0.000    0.000 /usr/lib/python3.7/abc.py:137(__instancecheck__)
#         1    0.000    0.000    6.058    6.058 <ipython-input-5-8b5562cd4f4b>:64(_generate_questions)
#        34    0.000    0.000    0.063    0.002 {built-in method builtins.all}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        63    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1386(<listcomp>)
#        49    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:244(_word_tokenizer_re)
#        11    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py:93(_event_pipe)
#        11    0.000    0.000    0.000    0.000 /usr/lib/python3.7/threading.py:1092(is_alive)
#        11    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000   11.454   11.454 <ipython-input-5-8b5562cd4f4b>:169(__call__)
#        63    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:726(prepare_for_tokenization)
#       126    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1947(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py:114(__init__)
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/__init__.py:84(sent_tokenize)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/compat.py:204(add_py3_data)
#         2    0.000    0.000    0.648    0.324 <ipython-input-5-8b5562cd4f4b>:93(_tokenize)
#       126    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py:809(build_inputs_with_special_tokens)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py:119(__enter__)
#        15    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1719(__init__)
#        51    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:426(type_no_sentperiod)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.7/enum.py:289(__call__)
#        60    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1588(<lambda>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/data.py:208(normalize_resource_name)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/data.py:752(load)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py:123(__exit__)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py:200(__init__)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py:307(_is_master_process)
#        53    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/data.py:152(normalize_resource_url)
#        11    0.000    0.000    0.000    0.000 /usr/lib/python3.7/threading.py:1050(_wait_for_tstate_lock)
#        16    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-8b5562cd4f4b>:88(<listcomp>)
#        12    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:169(__getitem__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.7/posixpath.py:338(normpath)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-8b5562cd4f4b>:61(<listcomp>)
#         8    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:749(pad_token)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1285(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:1013(get_output_embeddings)
#        31    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:807(adjust_logits_during_generation)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.7/posixpath.py:64(isabs)
#         2    0.000    0.000    0.000    0.000 {method 'expand' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-8b5562cd4f4b>:89(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/data.py:125(split_resource_url)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py:320(_schedule_flush)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.7/enum.py:531(__new__)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:841(pad_token_id)
#         6    0.000    0.000    0.000    0.000 {built-in method torch._C.is_grad_enabled}
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1278(sentences_from_text)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.7/types.py:164(__get__)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:436(first_upper)
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1233(tokenize)
#         1    0.000    0.000    0.005    0.005 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:1268(span_tokenize)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.7/re.py:182(search)
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'finditer' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py:1016(get_encoder)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py:131(is_torch_available)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.7/posixpath.py:41(_get_sep)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.7/re.py:187(sub)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.7/enum.py:633(value)
#        15    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-8b5562cd4f4b>:59(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:276(period_context_re)
#        11    0.000    0.000    0.000    0.000 /usr/lib/python3.7/threading.py:507(is_set)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.7/collections/__init__.py:1030(__iter__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1402(<listcomp>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/nltk/tokenize/punkt.py:441(first_lower)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/torch/_jit_internal.py:833(is_scripting)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 {method 'islower' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isupper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:1938(<genexpr>)
